# %% [markdown]
# # Placeholder
#
# Name the files names in the order you expect the TA to see their output.

# %% [markdown]
# assignment-1/01-assignment-part-1.ipynb
# assignment-1/low_rank_gaussians_1.ipynb
# assignment-1/low_rank_gaussians_2.ipynb
